# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
restaurant_file_path = '/Users/Paul/Sandbox/ygnite_proj/data/restaurant_inspection.csv'

# %%
df = pd.read_csv(restaurant_file_path, low_memory=False)
df
# Out:
#            CAMIS                         DBA           BORO    BUILDING  \
# 0       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 1       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 2       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 3       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 4       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 5       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 6       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 7       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 8       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 9       30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 10      30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# 11      30075445       MORRIS PARK BAKE SHOP          BRONX        1007
# ...

# %%
restaurant_names = df["DBA"]
restaurant_names[:1]
# Out:
# 0    MORRIS PARK BAKE SHOP
# Name: DBA, dtype: object

# %%
df[(df.DBA == "CARACAS AREPA BAR")]
# Out:
#            CAMIS                DBA       BORO    BUILDING  \
# 140528  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140529  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140530  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140531  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140532  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140533  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 140534  41191810  CARACAS AREPA BAR  MANHATTAN  939312
# 194150  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194151  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194152  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194153  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194154  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194155  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194156  41366593  CARACAS AREPA BAR   BROOKLYN         291
# 194157  41366593  CARACAS AREPA BAR   BROOKLYN         291
# ...

# %%
df['CUISINE DESCRIPTION'].unique()
# Out:
# array(['Bakery', 'Hamburgers', 'Irish', 'American ', 'Delicatessen',
#        'Ice Cream, Gelato, Yogurt, Ices', 'Hotdogs', 'Jewish/Kosher',
#        'Chicken', 'Chinese', 'Turkish', 'Caribbean', 'Donuts',
#        'Sandwiches/Salads/Mixed Buffet', 'Bagels/Pretzels', 'Continental',
#        'Pizza', 'Soul Food', 'Italian', 'Steak', 'Polish',
#        'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#        'German', 'French', 'Pizza/Italian', 'Mexican', 'Spanish',
#        'Caf\xc3\xa9/Coffee/Tea', 'Seafood', 'Tex-Mex', 'Pancakes/Waffles',
#        'African', 'Japanese', 'Greek', 'Armenian', 'Thai', 'Chinese/Cuban',
#        'Indian', 'Polynesian', 'Mediterranean', 'Korean',
#        'Caf\xc3\x83\xc2\xa9/Coffee/Tea', 'Russian', 'Eastern European',
#        'Asian', 'Ethiopian', 'Vegetarian', 'Barbecue', 'Middle Eastern',
#        'Egyptian', 'English', 'Other',
#        'Bottled beverages, including water, sodas, juices, etc.',
# ...

# %%
ktown_df = df[(df['CUISINE DESCRIPTION'] == 'Korean') & (korean_df['BORO'] == 'MANHATTAN')]
ktown_df
# Out:
#            CAMIS                         DBA       BORO    BUILDING  \
# 10298   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10299   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10304   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10305   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10319   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10320   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10327   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 10328   40378729  KANG SUH KOREAN RESTAURANT  MANHATTAN  1250
# 16979   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# 16980   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# 16981   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# 16982   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# 16983   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# 16984   40390696          HAN BAT RESTAURANT  MANHATTAN  53
# ...

# %%
ktown_df.groupby(['DBA']).size()
# Out:
# DBA
# 5 SENSES                                           1
# 5BAR KARAOKE                                       5
# AMBROSIA                                          13
# BAEKJEONG                                          3
# BANGIA BAR & LOUNGE                                8
# BANN                                              10
# BARN JOO                                           7
# BCD TOFU HOUSE                                    10
# BOKA                                               4
# BONCHON                                            4
# BUDDHA B BEEQ                                     10
# CAFFE BENE                                         3
# CHO DANG GOL                                       7
# CHORUS MUSIC STUDIO/ CHORUS KARAOKE LOUNGE BAR     8
# DANJI                                             16
# DDM YUPDDUK                                        2
# DO HWA                                            11
# DONs BOGAM                                         9
# ...

# %%
ktown_violations = pd.DataFrame({'count':ktown_df.groupby(['DBA'], as_index=False).size()}).reset_index()
ktown_violations
# Out:
#                                                DBA  count
# 0                                         5 SENSES      1
# 1                                     5BAR KARAOKE      5
# 2                                         AMBROSIA     13
# 3                                        BAEKJEONG      3
# 4                              BANGIA BAR & LOUNGE      8
# 5                                             BANN     10
# 6                                         BARN JOO      7
# 7                                   BCD TOFU HOUSE     10
# 8                                             BOKA      4
# 9                                          BONCHON      4
# 10                                   BUDDHA B BEEQ     10
# 11                                      CAFFE BENE      3
# 12                                    CHO DANG GOL      7
# 13  CHORUS MUSIC STUDIO/ CHORUS KARAOKE LOUNGE BAR      8
# 14                                           DANJI     16
# ...

# %%
ktown
# Out:
#                                                DBA  count
# 14                                           DANJI     16
# 52                                      MISS KOREA     14
# 2                                         AMBROSIA     13
# 71                         THE SPOT KARAOKE LOUNGE     11
# 51                          MILL KOREAN RESTAURANT     11
# 57                            NEW WONJO RESTAURANT     11
# 46                                         KYOCHON     11
# 16                                          DO HWA     11
# 31                                 ISLAND GLEN USA     11
# 35                                        JUNG SIK     10
# 28                                  HELL'S CHICKEN     10
# 72                                THIRD FLOOR CAFE     10
# 10                                   BUDDHA B BEEQ     10
# 36                                          K TOWN     10
# 42                         KOREAN TAKE OUT EXPRESS     10
# ...

# %%
ktown_df[(ktown_df.DBA == 'MISS KOREA')]
# Out:
#            CAMIS         DBA       BORO BUILDING            STREET  ZIPCODE  \
# 252783  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252784  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252789  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252790  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252791  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252792  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252794  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 252795  41503714  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 362341  41695803  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 362342  41695803  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# 362343  41695803  MISS KOREA  MANHATTAN       10  WEST   32 STREET    10001
# ...
