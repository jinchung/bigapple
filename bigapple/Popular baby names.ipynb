# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
baby_names = '/Users/jinchung/sandbox/bigapple-data/pop_baby_names.csv'

# %%
baby_names_df = pd.read_csv(baby_names)
baby_names_df
# Out:
#       BRTH_YR    GNDR                      ETHCTY         NM  CNT  RNK
# 0        2011  FEMALE  ASIAN AND PACIFIC ISLANDER    ABIGAIL   24   24
# 1        2011  FEMALE  ASIAN AND PACIFIC ISLANDER    ABIGAIL   24   24
# 2        2011  FEMALE  ASIAN AND PACIFIC ISLANDER    ABIGAIL   24   24
# 3        2011  FEMALE  ASIAN AND PACIFIC ISLANDER        ADA   13   35
# 4        2011  FEMALE  ASIAN AND PACIFIC ISLANDER        ADA   13   35
# 5        2011  FEMALE  ASIAN AND PACIFIC ISLANDER        ADA   13   35
# 6        2011  FEMALE  ASIAN AND PACIFIC ISLANDER      AISHA   13   35
# 7        2011  FEMALE  ASIAN AND PACIFIC ISLANDER      AISHA   13   35
# 8        2011  FEMALE  ASIAN AND PACIFIC ISLANDER      AISHA   13   35
# 9        2011  FEMALE  ASIAN AND PACIFIC ISLANDER       AIZA   10   38
# 10       2011  FEMALE  ASIAN AND PACIFIC ISLANDER       AIZA   10   38
# 11       2011  FEMALE  ASIAN AND PACIFIC ISLANDER       AIZA   10   38
# 12       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALEENA   12   36
# 13       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALEENA   12   36
# 14       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALEENA   12   36
# 15       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALEXA   10   38
# 16       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALEXA   10   38
# 17       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALEXA   10   38
# 18       2011  FEMALE  ASIAN AND PACIFIC ISLANDER  ALEXANDRA   13   35
# 19       2011  FEMALE  ASIAN AND PACIFIC ISLANDER  ALEXANDRA   13   35
# 20       2011  FEMALE  ASIAN AND PACIFIC ISLANDER  ALEXANDRA   13   35
# 21       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALICE   27   21
# 22       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALICE   27   21
# 23       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALICE   27   21
# 24       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALINA   25   23
# 25       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALINA   25   23
# 26       2011  FEMALE  ASIAN AND PACIFIC ISLANDER      ALINA   25   23
# 27       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALISHA   10   38
# 28       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALISHA   10   38
# 29       2011  FEMALE  ASIAN AND PACIFIC ISLANDER     ALISHA   10   38
# ...       ...     ...                         ...        ...  ...  ...
# 5859     2011    MALE          WHITE NON HISPANIC   YITZCHAK   17   90
# 5860     2011    MALE          WHITE NON HISPANIC   YITZCHAK   17   90
# 5861     2011    MALE          WHITE NON HISPANIC   YITZCHAK   17   90
# 5862     2011    MALE          WHITE NON HISPANIC   YITZCHOK   56   56
# 5863     2011    MALE          WHITE NON HISPANIC   YITZCHOK   56   56
# 5864     2011    MALE          WHITE NON HISPANIC   YITZCHOK   56   56
# 5865     2011    MALE          WHITE NON HISPANIC       YOEL   20   87
# 5866     2011    MALE          WHITE NON HISPANIC       YOEL   20   87
# 5867     2011    MALE          WHITE NON HISPANIC       YOEL   20   87
# 5868     2011    MALE          WHITE NON HISPANIC      YONAH   10   97
# 5869     2011    MALE          WHITE NON HISPANIC      YONAH   10   97
# 5870     2011    MALE          WHITE NON HISPANIC      YONAH   10   97
# 5871     2011    MALE          WHITE NON HISPANIC      YOSEF  102   28
# 5872     2011    MALE          WHITE NON HISPANIC      YOSEF  102   28
# 5873     2011    MALE          WHITE NON HISPANIC      YOSEF  102   28
# 5874     2011    MALE          WHITE NON HISPANIC     YOUSEF   12   95
# 5875     2011    MALE          WHITE NON HISPANIC     YOUSEF   12   95
# 5876     2011    MALE          WHITE NON HISPANIC     YOUSEF   12   95
# 5877     2011    MALE          WHITE NON HISPANIC    YOUSSEF   11   96
# 5878     2011    MALE          WHITE NON HISPANIC    YOUSSEF   11   96
# 5879     2011    MALE          WHITE NON HISPANIC    YOUSSEF   11   96
# 5880     2011    MALE          WHITE NON HISPANIC    ZACHARY   86   38
# 5881     2011    MALE          WHITE NON HISPANIC    ZACHARY   86   38
# 5882     2011    MALE          WHITE NON HISPANIC    ZACHARY   86   38
# 5883     2011    MALE          WHITE NON HISPANIC     ZALMEN   14   93
# 5884     2011    MALE          WHITE NON HISPANIC     ZALMEN   14   93
# 5885     2011    MALE          WHITE NON HISPANIC     ZALMEN   14   93
# 5886     2011    MALE          WHITE NON HISPANIC        ZEV   47   61
# 5887     2011    MALE          WHITE NON HISPANIC        ZEV   47   61
# 5888     2011    MALE          WHITE NON HISPANIC        ZEV   47   61
#
# [5889 rows x 6 columns]

# %%
baby_names_df = baby_names_df.drop_duplicates()
baby_names_df

# %%
# How many babies are we looking at?
baby_names_df['CNT'].sum()

# %%
# most popular male baby name
male_names_df = baby_names_df[(baby_names_df.GNDR == "MALE")]
male_names_df.sort_values(by='CNT', ascending=0)

# %%
# most popular female baby name
female_names_df = baby_names_df[(baby_names_df.GNDR == "FEMALE")]
female_names_df.sort_values(by='CNT', ascending=0)

# %%
# Give me all possible ethnicities
baby_names_df['ETHCTY'].unique()

# %%
# Asian baby names
asian_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "ASIAN AND PACIFIC ISLANDER")]
asian_baby_names_df.sort_values(by="CNT", ascending=0)

# %%
# Hispanic baby names
hispanic_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "HISPANIC")]
hispanic_baby_names_df.sort_values(by="CNT", ascending=0)

# %%
# What do you think is the most common hispanic baby name?
hispanic_baby_names_df[(hispanic_baby_names_df.NM == "MARIA")]

# %%
# Hispanic baby boy names
male_hispanic_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "HISPANIC") & (baby_names_df.GNDR == "MALE")]
male_hispanic_baby_names_df.sort_values(by="CNT", ascending=0)[:1]

# %%
# Hispanic baby girl names
female_hispanic_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "HISPANIC") & (baby_names_df.GNDR == "FEMALE")]
female_hispanic_baby_names_df.sort_values(by="CNT", ascending=0)[:1]

# %%
# Most popular Asian baby girl name
female_asian_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "ASIAN AND PACIFIC ISLANDER") & (baby_names_df.GNDR == "FEMALE")]
female_asian_baby_names_df.sort_values(by="CNT", ascending=0)[:1]

# %%
# Most popular Asian baby boy name
male_asian_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "ASIAN AND PACIFIC ISLANDER") & (baby_names_df.GNDR == "MALE")]
male_asian_baby_names_df.sort_values(by="CNT", ascending=0)[:1]

# %%
male_asian_baby_names_df = baby_names_df[(baby_names_df.ETHCTY == "ASIAN AND PACIFIC ISLANDER") & (baby_names_df.RNK == 1)]
male_asian_baby_names_df

# %%
# Top baby names by ethnicity
top_baby_names_df = baby_names_df[(baby_names_df.RNK == 1)]
top_baby_names_df

# %%
baby_names_df.groupby(['GNDR','NM'])

# %%
# What is the most popular female baby name?
all_female_baby_names = baby_names_df[(baby_names_df.GNDR == "FEMALE")]
all_female_baby_names = all_female_baby_names.groupby(['NM']).sum()
all_female_baby_names.sort_values(by='CNT', ascending=0)[:1]

# %%
# What is the most popular male baby name?
all_male_baby_names = baby_names_df[(baby_names_df.GNDR == "MALE")]
all_male_baby_names = all_male_baby_names.groupby(['NM']).sum()
all_male_baby_names.sort_values(by='CNT', ascending=0)[:1]
